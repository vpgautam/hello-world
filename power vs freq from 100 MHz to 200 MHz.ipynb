# %%
#################import libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0be021da1077> in <module>
#       3 import matplotlib
#       4 import matplotlib.pyplot as plt
# ----> 5 from IPython.display import image
#
# ImportError: cannot import name 'image'

# %%
test10020 = np.load('test100_205.npy');
test10030 = np.load('test100_3051.npy');
test10040 = np.load('test100_405.npy');
test10050 = np.load('test100_505.npy');
test10060 = np.load('test100_605.npy');

test10020 = test10020.astype(complex);
test10030 = test10030.astype(complex);
test10040 = test10040.astype(complex);
test10050 = test10050.astype(complex);


#######################################
test11020 = np.load('test110_205.npy');
test11030 = np.load('test110_3051.npy');
test11040 = np.load('test110_405.npy');
test11050 = np.load('test110_505.npy');
test11060 = np.load('test110_605.npy');

test11020 = test11020.astype(complex);
test11030 = test11030.astype(complex);
test11040 = test11040.astype(complex);
test11050 = test11050.astype(complex);


######################################
test12020 = np.load('test120_205.npy');
test12030 = np.load('test120_3051.npy');
test12040 = np.load('test120_405.npy');
test12050 = np.load('test120_505.npy');
test12060 = np.load('test120_605.npy');

test12020 = test12020.astype(complex);
test12030 = test12030.astype(complex);
test12040 = test12040.astype(complex);
test12050 = test12050.astype(complex);
test12060 = test12060.astype(complex);


######################################
test13020 = np.load('test130_205.npy');
test13030 = np.load('test130_3051.npy');
test13040 = np.load('test130_405.npy');
test13050 = np.load('test130_5053.npy');
test13060 = np.load('test130_605.npy');

test13020 = test13020.astype(complex);
test13030 = test13030.astype(complex);
test13040 = test13040.astype(complex);
test13050 = test13050.astype(complex);
test13060 = test13060.astype(complex);


######################################
test14020 = np.load('test140_205.npy');
test14030 = np.load('test140_3051.npy');
test14040 = np.load('test140_405.npy');
test14050 = np.load('test140_5053.npy');
test14060 = np.load('test140_605.npy');

test14020 = test14020.astype(complex);
test14030 = test14030.astype(complex);
test14040 = test14040.astype(complex);
test14050 = test14050.astype(complex);
test14060 = test14060.astype(complex);


#######################################
test15020 = np.load('test150_205.npy');
test15030 = np.load('test150_305.npy');
test15040 = np.load('test150_405.npy');
test15050 = np.load('test150_505.npy');
test15060 = np.load('test150_605.npy');

test15020 = test15020.astype(complex);
test15030 = test15030.astype(complex);
test15040 = test15040.astype(complex);
test15050 = test15050.astype(complex);
test15060 = test15060.astype(complex);

#######################################
test16020 = np.load('test160_205.npy');
test16030 = np.load('test160_305.npy');
test16040 = np.load('test160_405.npy');
test16050 = np.load('test160_505.npy');
test16060 = np.load('test160_605.npy');

test16020 = test16020.astype(complex);
test16030 = test16030.astype(complex);
test16040 = test16040.astype(complex);
test16050 = test16050.astype(complex);
test16060 = test16060.astype(complex);


###########################################
test17020 = np.load('test170_205.npy');
test17030 = np.load('test170_305.npy');
test17040 = np.load('test170_405.npy');
test17050 = np.load('test170_505.npy');
test17060 = np.load('test170_605.npy');

test17020 = test17020.astype(complex);
test17030 = test17030.astype(complex);
test17040 = test17040.astype(complex);
test17050 = test17050.astype(complex);
test17060 = test17060.astype(complex);

###########################################
test18020 = np.load('test180_205.npy');
test18030 = np.load('test180_305.npy');
test18040 = np.load('test180_405.npy');
test18050 = np.load('test180_505.npy');
test18060 = np.load('test180_605.npy');

test18020 = test18020.astype(complex);
test18030 = test18030.astype(complex);
test18040 = test18040.astype(complex);
test18050 = test18050.astype(complex);
test18060 = test18060.astype(complex);

############################################
test19020 = np.load('test190_205.npy');
test19030 = np.load('test190_305.npy');
test19040 = np.load('test190_405.npy');
test19050 = np.load('test190_505.npy');
test19060 = np.load('test190_605.npy');

test19020 = test19020.astype(complex);
test19030 = test19030.astype(complex);
test19040 = test19040.astype(complex);
test19050 = test19050.astype(complex);
test19060 = test19060.astype(complex)



##########################################
test20020 = np.load('test200_205.npy');
test20030 = np.load('test200_305.npy');
test20040 = np.load('test200_405.npy');
test20050 = np.load('test200_505.npy');
test20060 = np.load('test200_605.npy');


test20020 = test20020.astype(complex);
test20030 = test20030.astype(complex);
test20040 = test20040.astype(complex);
test20050 = test20050.astype(complex);
test20060 = test20060.astype(complex);

# %%
####################@150MHz
# %matplotlib notebook
frame = 50;




for i in range(0, frame):
    test10020[i] = test10020[i]- np.mean(test10020[i])

for i in range(0, frame):
    test11020[i] = test11020[i] - np.mean(test11020[i]);
    
for i in range(0,frame):
    test12020[i] = test12020[i] - np.mean(test12020[i]);
    
for i in range(0, frame):
    test13020[i] = test13020[i] - np.mean(test13020[i]);
    
for i in range(0, frame):
    test14020[i] = test14020[i] - np.mean(test14020[i]);
    

############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test10020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs10020 = np.abs(fft_array)
fft_avg=np.mean(abs10020[1:], axis = 0);
logfft10020= 20*np.log10(fft_avg);


inds10020 = np.where(logfft10020 == np.max(logfft10020));
max10020 = logfft10020[inds10020];
print(inds10020, logfft10020[inds10020],'averaged frames for minus 20 dBm @100 MHz');
plt.figure()
plt.plot(fft_freq, logfft10020, label = '-20 dBm @100MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test11020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs11020 = np.abs(fft_array)
fft_avg=np.mean(abs11020[1:], axis = 0);
logfft11020= 20*np.log10(fft_avg);


inds11020 = np.where(logfft11020 == np.max(logfft11020));
max11020 = logfft11020[inds11020];
print(inds11020, logfft11020[inds11020],'averaged frames for minus 20 dBm @110MHz');
#plt.figure()
plt.plot(fft_freq, logfft11020, label = '-20 dBm @110MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test12020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs12020 = np.abs(fft_array)
fft_avg=np.mean(abs12020[1:], axis = 0);
logfft12020= 20*np.log10(fft_avg);


inds12020 = np.where(logfft12020 == np.max(logfft12020));
max12020 = logfft12020[inds12020];
print(inds12020, logfft12020[inds12020],'averaged frames for minus 20 dBm @120MHz');
#plt.figure()
plt.plot(fft_freq, logfft12020, label = '-20 dBm @120MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test13020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs13020 = np.abs(fft_array)
fft_avg=np.mean(abs13020[1:], axis = 0);
logfft13020= 20*np.log10(fft_avg);


inds13020 = np.where(logfft13020 == np.max(logfft13020));
max13020 = logfft13020[inds13020];
print(inds13020, logfft13020[inds13020],'averaged frames for minus 20 dBm @130MHz');
#plt.figure()
plt.plot(fft_freq, logfft13020, label = '-20 dBm @130MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test14020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs14020 = np.abs(fft_array)
fft_avg=np.mean(abs14020[1:], axis = 0);
logfft14020= 20*np.log10(fft_avg);


inds14020 = np.where(logfft14020 == np.max(logfft14020));
max14020 = logfft14020[inds14020];
print(inds14020, logfft14020[inds14020],'averaged frames for minus 20 dBm @140MHz');
#plt.figure()
plt.plot(fft_freq, logfft14020, label = '-20 dBm @140MHz');
plt.legend(loc = 'best');
plt.xlabel('freq [Mhz]');
plt.ylabel('mag [dB]');



###################################################################################################################
outminus20_1dbm = [max10020, max11020, max12020, max13020, max14020]
# Out:
# (array([8050]),) [-6.89777442] averaged frames for minus 20 dBm @100 MHz
# <img src="data:," width="0">
# (array([8054]),) [-7.05602289] averaged frames for minus 20 dBm @110MHz
# (array([8060]),) [-7.21834706] averaged frames for minus 20 dBm @120MHz
# (array([8064]),) [-7.59156866] averaged frames for minus 20 dBm @130MHz
# (array([8069]),) [-6.67800141] averaged frames for minus 20 dBm @140MHz

# %%
####################@ in 30 dBm
# %matplotlib notebook
frame = 50;




for i in range(0, frame):
    test10030[i] = test10030[i]- np.mean(test10030[i])

for i in range(0, frame):
    test11030[i] = test11030[i] - np.mean(test11030[i]);
    
for i in range(0,frame):
    test12030[i] = test12030[i] - np.mean(test12030[i]);
    
for i in range(0, frame):
    test13030[i] = test13030[i] - np.mean(test13030[i]);
    
for i in range(0, frame):
    test14030[i] = test14030[i] - np.mean(test14030[i]);
    

############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test10030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs10030 = np.abs(fft_array)
fft_avg=np.mean(abs10030[1:], axis = 0);
logfft10030= 20*np.log10(fft_avg);


inds10030 = np.where(logfft10030 == np.max(logfft10030));
max10030 = logfft10030[inds10030];
print(inds10030, logfft10030[inds10030],'averaged frames for minus 20 dBm @100 MHz');
plt.figure()
plt.plot(fft_freq, logfft10030, label = '-30 dBm @100MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test11030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs11030 = np.abs(fft_array)
fft_avg=np.mean(abs11030[1:], axis = 0);
logfft11030= 20*np.log10(fft_avg);


inds11030 = np.where(logfft11030 == np.max(logfft11030));
max11030 = logfft11030[inds11030];
print(inds11030, logfft11030[inds11030],'averaged frames for minus 30 dBm @110MHz');
#plt.figure()
plt.plot(fft_freq, logfft11030, label = '-30 dBm @110MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test12030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs12030 = np.abs(fft_array)
fft_avg=np.mean(abs12030[1:], axis = 0);
logfft12030= 20*np.log10(fft_avg);


inds12030 = np.where(logfft12030 == np.max(logfft12030));
max12030 = logfft12030[inds12030];
print(inds12030, logfft12030[inds12030],'averaged frames for minus 30 dBm @120MHz');
#plt.figure()
plt.plot(fft_freq, logfft12030, label = '-30 dBm @120MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test13030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs13030 = np.abs(fft_array)
fft_avg=np.mean(abs13030[1:], axis = 0);
logfft13030= 20*np.log10(fft_avg);


inds13030 = np.where(logfft13030 == np.max(logfft13030));
max13030 = logfft13030[inds13030];
print(inds13030, logfft13030[inds13030],'averaged frames for minus 30 dBm @130MHz');
#plt.figure()
plt.plot(fft_freq, logfft13030, label = '-30 dBm @130MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test14030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs14030 = np.abs(fft_array)
fft_avg=np.mean(abs14030[1:], axis = 0);
logfft14030= 20*np.log10(fft_avg);


inds14030 = np.where(logfft14030 == np.max(logfft14030));
max14030 = logfft14030[inds14030];
print(inds14030, logfft14030[inds14030],'averaged frames for minus 30 dBm @140MHz');
#plt.figure()
plt.plot(fft_freq, logfft14030, label = '-30 dBm @140MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');



###################################################################################################################
outminus30_1dbm = [max10030, max11030, max12030, max13030, max14030]
# Out:
# (array([8050]),) [-16.72855944] averaged frames for minus 20 dBm @100 MHz
# <img src="data:," width="0">
# (array([8054]),) [-16.81992805] averaged frames for minus 30 dBm @110MHz
# (array([8060]),) [-16.92718259] averaged frames for minus 30 dBm @120MHz
# (array([8064]),) [-17.24162695] averaged frames for minus 30 dBm @130MHz
# (array([8069]),) [-16.11104666] averaged frames for minus 30 dBm @140MHz

# %%
####################@ in 40 dBm
# %matplotlib notebook
frame = 50;




for i in range(0, frame):
    test10040[i] = test10040[i]- np.mean(test10040[i])

for i in range(0, frame):
    test11040[i] = test11040[i] - np.mean(test11040[i]);
    
for i in range(0,frame):
    test12040[i] = test12040[i] - np.mean(test12040[i]);
    
for i in range(0, frame):
    test13040[i] = test13040[i] - np.mean(test13040[i]);
    
for i in range(0, frame):
    test14040[i] = test14040[i] - np.mean(test14040[i]);
    

############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test10040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs10040 = np.abs(fft_array)
fft_avg=np.mean(abs10040[1:], axis = 0);
logfft10040= 20*np.log10(fft_avg);


inds10040 = np.where(logfft10040 == np.max(logfft10040));
max10040 = logfft10040[inds10040];
print(inds10040, logfft10040[inds10040],'averaged frames for minus 40 dBm @100 MHz');
plt.figure()
plt.plot(fft_freq, logfft10040, label = '-40 dBm @100MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test11040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs11040 = np.abs(fft_array)
fft_avg=np.mean(abs11040[1:], axis = 0);
logfft11040= 20*np.log10(fft_avg);


inds11040 = np.where(logfft11040 == np.max(logfft11040));
max11040 = logfft11040[inds11040];
print(inds11040, logfft11040[inds11040],'averaged frames for minus 40 dBm @110MHz');
#plt.figure()
plt.plot(fft_freq, logfft11040, label = '-40 dBm @110MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test12040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs12040 = np.abs(fft_array)
fft_avg=np.mean(abs12040[1:], axis = 0);
logfft12040= 20*np.log10(fft_avg);


inds12040 = np.where(logfft12040 == np.max(logfft12040));
max12040 = logfft12040[inds12040];
print(inds12040, logfft12040[inds12040],'averaged frames for minus 40 dBm @120MHz');
#plt.figure()
plt.plot(fft_freq, logfft12040, label = '-40 dBm @120MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test13040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs13040 = np.abs(fft_array)
fft_avg=np.mean(abs13040[1:], axis = 0);
logfft13040= 20*np.log10(fft_avg);


inds13040 = np.where(logfft13040 == np.max(logfft13040));
max13040 = logfft13040[inds13040];
print(inds13040, logfft13040[inds13040],'averaged frames for minus 40 dBm @130MHz');
#plt.figure()
plt.plot(fft_freq, logfft13040, label = '-40 dBm @130MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test14040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs14040 = np.abs(fft_array)
fft_avg=np.mean(abs14040[1:], axis = 0);
logfft14040= 20*np.log10(fft_avg);


inds14040 = np.where(logfft14040 == np.max(logfft14040));
max14040 = logfft14040[inds14040];
print(inds14040, logfft14040[inds14040],'averaged frames for minus 40 dBm @140MHz');
#plt.figure()
plt.plot(fft_freq, logfft14040, label = '-40 dBm @140MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');



###################################################################################################################
outminus40_1dbm = [max10040, max11040, max12040, max13040, max14040]
# Out:
# (array([8050]),) [-26.99644151] averaged frames for minus 40 dBm @100 MHz
# <img src="data:," width="0">
# (array([8054]),) [-27.09224145] averaged frames for minus 40 dBm @110MHz
# (array([8060]),) [-27.19176197] averaged frames for minus 40 dBm @120MHz
# (array([8064]),) [-27.41700731] averaged frames for minus 40 dBm @130MHz
# (array([8069]),) [-26.38334726] averaged frames for minus 40 dBm @140MHz

# %%
####################@ in 40 dBm
# %matplotlib notebook
frame = 50;




for i in range(0, frame):
    test10050[i] = test10050[i]- np.mean(test10050[i])

for i in range(0, frame):
    test11050[i] = test11050[i] - np.mean(test11050[i]);
    
for i in range(0,frame):
    test12050[i] = test12050[i] - np.mean(test12050[i]);
    
for i in range(0, frame):
    test13050[i] = test13050[i] - np.mean(test13050[i]);
    
for i in range(0, frame):
    test14050[i] = test14050[i] - np.mean(test14050[i]);
    

############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test10050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs10050 = np.abs(fft_array)
fft_avg=np.mean(abs10050[1:], axis = 0);
logfft10050= 20*np.log10(fft_avg);


inds10050 = np.where(logfft10050 == np.max(logfft10050));
max10050 = logfft10050[inds10050];
print(inds10050, logfft10050[inds10050],'averaged frames for minus 50 dBm @100 MHz');
plt.figure()
plt.plot(fft_freq, logfft10050, label = '-50 dBm @100MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test11050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs11050 = np.abs(fft_array)
fft_avg=np.mean(abs11050[1:], axis = 0);
logfft11050= 20*np.log10(fft_avg);


inds11050 = np.where(logfft11050 == np.max(logfft11050));
max11050 = logfft11050[inds11050];
print(inds11050, logfft11050[inds11050],'averaged frames for minus 50 dBm @110MHz');
#plt.figure()
plt.plot(fft_freq, logfft11050, label = '-50 dBm @110MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test12050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs12050 = np.abs(fft_array)
fft_avg=np.mean(abs12050[1:], axis = 0);
logfft12050= 20*np.log10(fft_avg);


inds12050 = np.where(logfft12050 == np.max(logfft12050));
max12050 = logfft12050[inds12050];
print(inds12050, logfft12050[inds12050],'averaged frames for minus 50 dBm @120MHz');
#plt.figure()
plt.plot(fft_freq, logfft12050, label = '-50 dBm @120MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test13050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs13050 = np.abs(fft_array)
fft_avg=np.mean(abs13050[1:], axis = 0);
logfft13050= 20*np.log10(fft_avg);


inds13050 = np.where(logfft13050 == np.max(logfft13050));
max13050 = logfft13050[inds13050];
print(inds13050, logfft13050[inds13050],'averaged frames for minus 50 dBm @130MHz');
#plt.figure()
plt.plot(fft_freq, logfft13050, label = '-50 dBm @130MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test14050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs14050 = np.abs(fft_array)
fft_avg=np.mean(abs14050[1:], axis = 0);
logfft14050= 20*np.log10(fft_avg);


inds14050 = np.where(logfft14050 == np.max(logfft14050));
max14050 = logfft14050[inds14050];
print(inds14050, logfft14050[inds14050],'averaged frames for minus 50 dBm @140MHz');
#plt.figure()
plt.plot(fft_freq, logfft14050, label = '-50 dBm @140MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');



###################################################################################################################
outminus50_1dbm = [max10050, max11050, max12050, max13050, max14050]
# Out:
# (array([8050]),) [-36.87861436] averaged frames for minus 50 dBm @100 MHz
# <img src="data:image/png;base64,..." width="640">
# (array([8054]),) [-36.97934536] averaged frames for minus 50 dBm @110MHz
# (array([8060]),) [-37.16458302] averaged frames for minus 50 dBm @120MHz
# (array([8064]),) [-37.38775396] averaged frames for minus 50 dBm @130MHz
# (array([8069]),) [-36.28802394] averaged frames for minus 50 dBm @140MHz

# %%
####################@ in 40 dBm
# %matplotlib notebook
frame = 50;




for i in range(0, frame):
    test10060[i] = test10060[i]- np.mean(test10060[i])

for i in range(0, frame):
    test11060[i] = test11060[i] - np.mean(test11060[i]);
    
for i in range(0,frame):
    test12060[i] = test12060[i] - np.mean(test12060[i]);
    
for i in range(0, frame):
    test13060[i] = test13060[i] - np.mean(test13060[i]);
    
for i in range(0, frame):
    test14060[i] = test14060[i] - np.mean(test14060[i]);
    

############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test10060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs10060 = np.abs(fft_array)
fft_avg=np.mean(abs10060[1:], axis = 0);
logfft10060= 20*np.log10(fft_avg);


inds10060 = np.where(logfft10060 == np.max(logfft10060));
max10060 = logfft10060[inds10060];
print(inds10060, logfft10060[inds10060],'averaged frames for minus 60 dBm @100 MHz');
plt.figure()
plt.plot(fft_freq, logfft10060, label = '-60 dBm @100MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test11060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs11060 = np.abs(fft_array)
fft_avg=np.mean(abs11060[1:], axis = 0);
logfft11060= 20*np.log10(fft_avg);


inds11060 = np.where(logfft11060 == np.max(logfft11060));
max11060 = logfft11060[inds11060];
print(inds11060, logfft11060[inds11060],'averaged frames for minus 60 dBm @110MHz');
#plt.figure()
plt.plot(fft_freq, logfft11060, label = '-60 dBm @110MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test12060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs12060 = np.abs(fft_array)
fft_avg=np.mean(abs12060[1:], axis = 0);
logfft12060= 20*np.log10(fft_avg);


inds12060 = np.where(logfft12060 == np.max(logfft12060));
max12060 = logfft12060[inds12060];
print(inds12060, logfft12060[inds12060],'averaged frames for minus 60 dBm @120MHz');
#plt.figure()
plt.plot(fft_freq, logfft12060, label = '-60 dBm @120MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test13060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs13060 = np.abs(fft_array)
fft_avg=np.mean(abs13060[1:], axis = 0);
logfft13060= 20*np.log10(fft_avg);


inds13060 = np.where(logfft13060 == np.max(logfft13060));
max13060 = logfft13060[inds13060];
print(inds13060, logfft13060[inds13060],'averaged frames for minus 60 dBm @130MHz');
#plt.figure()
plt.plot(fft_freq, logfft13060, label = '-60 dBm @130MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test14060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs14060 = np.abs(fft_array)
fft_avg=np.mean(abs14060[1:], axis = 0);
logfft14060= 20*np.log10(fft_avg);


inds14060 = np.where(logfft14060 == np.max(logfft14060));
max14060 = logfft14060[inds14060];
print(inds14060, logfft14060[inds14060],'averaged frames for minus 60 dBm @140MHz');
#plt.figure()
plt.plot(fft_freq, logfft14060, label = '-60 dBm @140MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');



###################################################################################################################
outminus60_1dbm = [max10060, max11060, max12060, max13060, max14060]
# Out:
# (array([8050]),) [-46.90129243] averaged frames for minus 60 dBm @100 MHz
# <img src="data:image/png;base64,..." width="640">
# (array([8054]),) [-47.01192802] averaged frames for minus 60 dBm @110MHz
# (array([8060]),) [-47.21561644] averaged frames for minus 60 dBm @120MHz
# (array([8064]),) [-47.41405115] averaged frames for minus 60 dBm @130MHz
# (array([8069]),) [-46.41192448] averaged frames for minus 60 dBm @140MHz

# %%
####################@150MHz
# %matplotlib notebook
frame = 50;




for i in range(0, frame):
    test15020[i] = test15020[i]- np.mean(test15020[i])

for i in range(0, frame):
    test16020[i] = test16020[i] - np.mean(test16020[i]);
    
for i in range(0,frame):
    test17020[i] = test17020[i] - np.mean(test17020[i]);
    
for i in range(0, frame):
    test18020[i] = test18020[i] - np.mean(test18020[i]);
    
for i in range(0, frame):
    test19020[i] = test19020[i] - np.mean(test19020[i]);
    
for i in range(0, frame):
    test20020[i] = test20020[i] - np.mean(test20020[i]);
    
############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test15020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs15020 = np.abs(fft_array)
fft_avg=np.mean(abs15020[1:], axis = 0);
logfft15020= 20*np.log10(fft_avg);


inds15020 = np.where(logfft15020 == np.max(logfft15020));
max15020 = logfft15020[inds15020];
print(inds15020, logfft15020[inds15020],'averaged frames for minus 20 dBm @150 MHz');
plt.figure()
plt.plot(fft_freq, logfft15020, label = '-20 dBm @150MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test16020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs16020 = np.abs(fft_array)
fft_avg=np.mean(abs16020[1:], axis = 0);
logfft16020= 20*np.log10(fft_avg);


inds16020 = np.where(logfft16020 == np.max(logfft16020));
max16020 = logfft16020[inds16020];
print(inds16020, logfft16020[inds16020],'averaged frames for minus 20 dBm @160MHz');
#plt.figure()
plt.plot(fft_freq, logfft16020, label = '-20 dBm @160MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test17020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs17020 = np.abs(fft_array)
fft_avg=np.mean(abs17020[1:], axis = 0);
logfft17020= 20*np.log10(fft_avg);


inds17020 = np.where(logfft17020 == np.max(logfft17020));
max17020 = logfft17020[inds17020];
print(inds17020, logfft17020[inds17020],'averaged frames for minus 20 dBm @170MHz');
#plt.figure()
plt.plot(fft_freq, logfft17020, label = '-20 dBm @170MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test18020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs18020 = np.abs(fft_array)
fft_avg=np.mean(abs18020[1:], axis = 0);
logfft18020= 20*np.log10(fft_avg);


inds18020 = np.where(logfft18020 == np.max(logfft18020));
max18020 = logfft18020[inds18020];
print(inds18020, logfft18020[inds18020],'averaged frames for minus 20 dBm @180MHz');
#plt.figure()
plt.plot(fft_freq, logfft18020, label = '-20 dBm @180MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test19020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs19020 = np.abs(fft_array)
fft_avg=np.mean(abs19020[1:], axis = 0);
logfft19020= 20*np.log10(fft_avg);


inds19020 = np.where(logfft19020 == np.max(logfft19020));
max19020 = logfft19020[inds19020];
print(inds19020, logfft19020[inds19020],'averaged frames for minus 20 dBm @190MHz');
#plt.figure()
plt.plot(fft_freq, logfft19020, label = '-20 dBm @190MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###################################################################################################################
for i in range(0, frame):
    x = test20020[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs20020 = np.abs(fft_array)
fft_avg=np.mean(abs20020[1:], axis = 0);
logfft20020= 20*np.log10(fft_avg);


inds20020 = np.where(logfft20020 == np.max(logfft20020));
max20020 = logfft20020[inds20020];
print(inds20020, logfft20020[inds20020],'averaged frames for minus 20 dBm @200MHz');
#plt.figure()
plt.plot(fft_freq, logfft20020, label = '-20 dBm @200MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###################################################################################################################
outminus20_2dbm = [max15020, max16020, max17020, max18020, max19020, max20020];
# Out:
# (array([8075]),) [-7.31901334] averaged frames for minus 20 dBm @150 MHz
# <img src="data:image/png;base64,..." width="640">
# (array([8079]),) [-6.69935741] averaged frames for minus 20 dBm @160MHz
# (array([8084]),) [-6.18207069] averaged frames for minus 20 dBm @170MHz
# (array([8088]),) [-6.49326405] averaged frames for minus 20 dBm @180MHz
# (array([8093]),) [-6.4232188] averaged frames for minus 20 dBm @190MHz
# (array([8099]),) [-6.19969117] averaged frames for minus 20 dBm @200MHz

# %%
####################@-30 dBm
# %matplotlib notebook
frame = 50;
for i in range(0, frame):
    test15030[i] = test15030[i]- np.mean(test15030[i])

for i in range(0, frame):
    test16030[i] = test16030[i] - np.mean(test16030[i]);
    
for i in range(0,frame):
    test17030[i] = test17030[i] - np.mean(test17030[i]);
    
for i in range(0, frame):
    test18030[i] = test18030[i] - np.mean(test18030[i]);
    
for i in range(0, frame):
    test19030[i] = test19030[i] - np.mean(test19030[i]);
    
for i in range(0, frame):
    test20030[i] = test20030[i] - np.mean(test20030[i]);
    
############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test15030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs15030 = np.abs(fft_array)
fft_avg=np.mean(abs15030[1:], axis = 0);
logfft15030= 20*np.log10(fft_avg);


inds15030 = np.where(logfft15030 == np.max(logfft15030));
max15030 = logfft15030[inds15030];
print(inds15030, logfft15030[inds15030],'averaged frames for minus 30 dBm @150 MHz');
plt.figure()
plt.plot(fft_freq, logfft15030, label = '-30 dBm @150MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test16030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs16030 = np.abs(fft_array)
fft_avg=np.mean(abs16030[1:], axis = 0);
logfft16030= 20*np.log10(fft_avg);


inds16030 = np.where(logfft16030 == np.max(logfft16030));
max16030 = logfft16030[inds16030];
print(inds16030, logfft16030[inds16030],'averaged frames for minus 30 dBm @160MHz');
#plt.figure()
plt.plot(fft_freq, logfft16030, label = '-30 dBm @160MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test17030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs17030 = np.abs(fft_array)
fft_avg=np.mean(abs17030[1:], axis = 0);
logfft17030= 20*np.log10(fft_avg);


inds17030 = np.where(logfft17030 == np.max(logfft17030));
max17030 = logfft17030[inds17030];
print(inds17030, logfft17030[inds17030],'averaged frames for minus 30 dBm @170MHz');
#plt.figure()
plt.plot(fft_freq, logfft17030, label = '-30 dBm @170MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test18030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs18030 = np.abs(fft_array)
fft_avg=np.mean(abs18030[1:], axis = 0);
logfft18030= 20*np.log10(fft_avg);


inds18030 = np.where(logfft18030 == np.max(logfft18030));
max18030 = logfft18030[inds18030];
print(inds18030, logfft18030[inds18030],'averaged frames for minus 30 dBm @180MHz');
#plt.figure()
plt.plot(fft_freq, logfft18030, label = '-30 dBm @180MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test19030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs19030 = np.abs(fft_array)
fft_avg=np.mean(abs19030[1:], axis = 0);
logfft19030= 20*np.log10(fft_avg);


inds19030 = np.where(logfft19030 == np.max(logfft19030));
max19030 = logfft19030[inds19030];
print(inds19030, logfft19030[inds19030],'averaged frames for minus 30 dBm @190MHz');
#plt.figure()
plt.plot(fft_freq, logfft19030, label = '-30 dBm @190MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###################################################################################################################
for i in range(0, frame):
    x = test20030[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs20030 = np.abs(fft_array)
fft_avg=np.mean(abs20030[1:], axis = 0);
logfft20030= 20*np.log10(fft_avg);


inds20030 = np.where(logfft20030 == np.max(logfft20030));
max20030 = logfft20030[inds20030];
print(inds20030, logfft20030[inds20030],'averaged frames for minus 30 dBm @200MHz');
#plt.figure()
plt.plot(fft_freq, logfft20030, label = '-30 dBm @200MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('mag [dB]');

###################################################################################################################

outminus30_2dbm = [max15030, max16030, max17030, max18030, max19030, max20030];
# Out:
# (array([8075]),) [-16.38033491] averaged frames for minus 30 dBm @150 MHz
# <img src="data:image/png;base64,..." width="640">
# (array([8079]),) [-15.39218337] averaged frames for minus 30 dBm @160MHz
# (array([8084]),) [-14.29125509] averaged frames for minus 30 dBm @170MHz
# (array([8088]),) [-14.23700903] averaged frames for minus 30 dBm @180MHz
# (array([8093]),) [-13.72964967] averaged frames for minus 30 dBm @190MHz
# (array([8099]),) [-13.13307843] averaged frames for minus 30 dBm @200MHz

# %%
####################@-40 dBm
# %matplotlib notebook
frame = 50;
for i in range(0, frame):
    test15040[i] = test15040[i]- np.mean(test15040[i])

for i in range(0, frame):
    test16040[i] = test16040[i] - np.mean(test16040[i]);
    
for i in range(0,frame):
    test17040[i] = test17040[i] - np.mean(test17040[i]);
    
for i in range(0, frame):
    test18040[i] = test18040[i] - np.mean(test18040[i]);
    
for i in range(0, frame):
    test19040[i] = test19040[i] - np.mean(test19040[i]);
    
for i in range(0, frame):
    test20040[i] = test20040[i] - np.mean(test20040[i]);
    
############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test15040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs15040 = np.abs(fft_array)
fft_avg=np.mean(abs15040[1:], axis = 0);
logfft15040= 20*np.log10(fft_avg);


inds15040 = np.where(logfft15040 == np.max(logfft15040));
max15040 = logfft15040[inds15040];
print(inds15040, logfft15040[inds15040],'averaged frames for minus 40 dBm @150 MHz');
plt.figure()
plt.plot(fft_freq, logfft15040, label = '-40 dBm @150MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test16040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs16040 = np.abs(fft_array)
fft_avg=np.mean(abs16040[1:], axis = 0);
logfft16040= 20*np.log10(fft_avg);


inds16040 = np.where(logfft16040 == np.max(logfft16040));
max16040 = logfft16040[inds16040];
print(inds16040, logfft16040[inds16040],'averaged frames for minus 40 dBm @160MHz');
#plt.figure()
plt.plot(fft_freq, logfft16040, label = '-40 dBm @160MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test17040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs17040 = np.abs(fft_array)
fft_avg=np.mean(abs17040[1:], axis = 0);
logfft17040= 20*np.log10(fft_avg);


inds17040 = np.where(logfft17040 == np.max(logfft17040));
max17040 = logfft17040[inds17040];
print(inds17040, logfft17040[inds17040],'averaged frames for minus 40 dBm @170MHz');
#plt.figure()
plt.plot(fft_freq, logfft17040, label = '-40 dBm @170MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test18040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs18040 = np.abs(fft_array)
fft_avg=np.mean(abs18040[1:], axis = 0);
logfft18040= 20*np.log10(fft_avg);


inds18040 = np.where(logfft18040 == np.max(logfft18040));
max18040 = logfft18040[inds18040];
print(inds18040, logfft18040[inds18040],'averaged frames for minus 40 dBm @180MHz');
#plt.figure()
plt.plot(fft_freq, logfft18040, label = '-40 dBm @180MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test19040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs19040 = np.abs(fft_array)
fft_avg=np.mean(abs19040[1:], axis = 0);
logfft19040= 20*np.log10(fft_avg);


inds19040 = np.where(logfft19040 == np.max(logfft19040));
max19040 = logfft19040[inds19040];
print(inds19040, logfft19040[inds19040],'averaged frames for minus 40 dBm @190MHz');
#plt.figure()
plt.plot(fft_freq, logfft19040, label = '-40 dBm @190MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###################################################################################################################
for i in range(0, frame):
    x = test20040[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
     
abs20040 = np.abs(fft_array)
fft_avg=np.mean(abs20040[1:], axis = 0);
logfft20040= 20*np.log10(fft_avg);


inds20040 = np.where(logfft20040 == np.max(logfft20040));
max20040 = logfft20040[inds20040];
print(inds20040, logfft20040[inds20040],'averaged frames for minus 40 dBm @200MHz');
#plt.figure()
plt.plot(fft_freq, logfft20040, label = '-40 dBm @200MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###############################################################################################################
outminus40_2dbm = [max15040, max16040, max17040, max18040, max19040, max20040];
# Out:
# (array([8075]),) [-26.702925] averaged frames for minus 40 dBm @150 MHz
# <img src="data:image/png;base64,..." width="640">
# (array([8079]),) [-25.74223733] averaged frames for minus 40 dBm @160MHz
# (array([8084]),) [-24.58526992] averaged frames for minus 40 dBm @170MHz
# (array([8088]),) [-24.53139144] averaged frames for minus 40 dBm @180MHz
# (array([8093]),) [-24.0494439] averaged frames for minus 40 dBm @190MHz
# (array([8099]),) [-23.35964398] averaged frames for minus 40 dBm @200MHz

# %%
####################calculating the SNR for -40dBm @150MHz
log15040 = np.array(logfft15040);
amp15040 = np.power(10, log15040/20);
pow15040 = np.power(amp15040/np.sqrt(2), 2);
totpow15040 = np.sum(pow15040);
sigpow15040 = pow15040[8075];
noisepow15040 = totpow15040 - sigpow15040;

SNR = 10*np.log10(sigpow15040/noisepow15040);
print('signal to noise power ratio of the output after averaging -40dBm input signal at 150MHz is  ', SNR);
# Out:
# signal to noise power ratio of the output after averaging -40dBm input signal at 150MHz is   0.6398938042731804

# %%
####################@-50 dBm
# %matplotlib notebook
frame = 50;
for i in range(0, frame):
    test15050[i] = test15050[i]- np.mean(test15050[i])

for i in range(0, frame):
    test16050[i] = test16050[i] - np.mean(test16050[i]);
    
for i in range(0,frame):
    test17050[i] = test17050[i] - np.mean(test17050[i]);
    
for i in range(0, frame):
    test18050[i] = test18050[i] - np.mean(test18050[i]);
    
for i in range(0, frame):
    test19050[i] = test19050[i] - np.mean(test19050[i]);
    
for i in range(0, frame):
    test20050[i] = test20050[i] - np.mean(test20050[i]);
    
############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test15050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs15050 = np.abs(fft_array)
fft_avg=np.mean(abs15050[1:], axis = 0);
logfft15050= 20*np.log10(fft_avg);


inds15050 = np.where(logfft15050 == np.max(logfft15050));
max15050 = logfft15050[inds15050];
print(inds15050, logfft15050[inds15050],'averaged frames for minus 50 dBm @150 MHz');
plt.figure()
plt.plot(fft_freq, logfft15050, label = '-50 dBm @150MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test16050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs16050 = np.abs(fft_array)
fft_avg=np.mean(abs16050[1:], axis = 0);
logfft16050= 20*np.log10(fft_avg);


inds16050 = np.where(logfft16050 == np.max(logfft16050));
max16050 = logfft16050[inds16050];
print(inds16050, logfft16050[inds16050],'averaged frames for minus 50 dBm @160MHz');
#plt.figure()
plt.plot(fft_freq, logfft16050, label = '-50 dBm @160MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test17050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs17050 = np.abs(fft_array)
fft_avg=np.mean(abs17050[1:], axis = 0);
logfft17050= 20*np.log10(fft_avg);


inds17050 = np.where(logfft17050 == np.max(logfft17050));
max17050 = logfft17050[inds17050];
print(inds17050, logfft17050[inds17050],'averaged frames for minus 50 dBm @170MHz');
#plt.figure()
plt.plot(fft_freq, logfft17050, label = '-50 dBm @170MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test18050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs18050 = np.abs(fft_array)
fft_avg=np.mean(abs18050[1:], axis = 0);
logfft18050= 20*np.log10(fft_avg);


inds18050 = np.where(logfft18050 == np.max(logfft18050));
max18050 = logfft18050[inds18050];
print(inds18050, logfft18050[inds18050],'averaged frames for minus 50 dBm @180MHz');
#plt.figure()
plt.plot(fft_freq, logfft18050, label = '-50 dBm @180MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test19050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs19050 = np.abs(fft_array)
fft_avg=np.mean(abs19050[1:], axis = 0);
logfft19050= 20*np.log10(fft_avg);


inds19050 = np.where(logfft19050 == np.max(logfft19050));
max19050 = logfft19050[inds19050];
print(inds19050, logfft19050[inds19050],'averaged frames for minus 50 dBm @190MHz');
#plt.figure()
plt.plot(fft_freq, logfft19050, label = '-50 dBm @190MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###################################################################################################################
for i in range(0, frame):
    x = test20050[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs20050 = np.abs(fft_array)
fft_avg=np.mean(abs20050[1:], axis = 0);
logfft20050= 20*np.log10(fft_avg);


inds20050 = np.where(logfft20050 == np.max(logfft20050));
max20050 = logfft20050[inds20050];
print(inds20050, logfft20050[inds20050],'averaged frames for minus 50 dBm @200MHz');
#plt.figure()
plt.plot(fft_freq, logfft20050, label = '-50 dBm @200MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

###################################################################################################################
outminus50_2dbm = [max15050, max16050, max17050, max18050, max19050, max20050];
# Out:
# (array([8075]),) [-36.60672984] averaged frames for minus 50 dBm @150 MHz
# <img src="data:," width="0">
# (array([8079]),) [-35.51666586] averaged frames for minus 50 dBm @160MHz
# (array([8084]),) [-34.46211837] averaged frames for minus 50 dBm @170MHz
# (array([8088]),) [-34.42546243] averaged frames for minus 50 dBm @180MHz
# (array([8093]),) [-33.86530902] averaged frames for minus 50 dBm @190MHz
# (array([8099]),) [-33.35649927] averaged frames for minus 50 dBm @200MHz

# %%
####################@-60 dBm
# %matplotlib notebook
frame = 50;
for i in range(0, frame):
    test15060[i] = test15060[i]- np.mean(test15060[i])

for i in range(0, frame):
    test16060[i] = test16060[i] - np.mean(test16060[i]);
    
for i in range(0,frame):
    test17060[i] = test17060[i] - np.mean(test17060[i]);
    
for i in range(0, frame):
    test18060[i] = test18060[i] - np.mean(test18060[i]);
    
for i in range(0, frame):
    test19060[i] = test19060[i] - np.mean(test19060[i]);
    
for i in range(0, frame):
    test20060[i] = test20060[i] - np.mean(test20060[i]);
    
############################################
NFFT = 16384;
fs = 2.048;###########sampling frequency in MHz
fft_freq = np.arange(start=0, stop = NFFT)*fs/NFFT;
frame = 50;






fft_array = np.zeros([frame, 16384], dtype = complex);
wind = np.hanning(16384);
fft_feq = np.arange(start = 0, stop =NFFT)*fs/NFFT;

for i in range(0, frame):
    x = test15060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs15060 = np.abs(fft_array)
fft_avg=np.mean(abs15060[1:], axis = 0);
logfft15060= 20*np.log10(fft_avg);


inds15060 = np.where(logfft15060 == np.max(logfft15060));
max15060 = logfft15060[inds15060];
print(inds15060, logfft15060[inds15060],'averaged frames for minus 60 dBm @150 MHz');
plt.figure()
plt.plot(fft_freq, logfft15060, label = '-60 dBm @150MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');
#plt.show();



###################################################################################################################
for i in range(0, frame):
    x = test16060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs16060 = np.abs(fft_array)
fft_avg=np.mean(abs16060[1:], axis = 0);
logfft16060= 20*np.log10(fft_avg);


inds16060 = np.where(logfft16060 == np.max(logfft16060));
max16060 = logfft16060[inds16060];
print(inds16060, logfft16060[inds16060],'averaged frames for minus 60 dBm @160MHz');
#plt.figure()
plt.plot(fft_freq, logfft16060, label = '-60 dBm @160MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

##################################################################################################################
for i in range(0, frame):
    x = test17060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs17060 = np.abs(fft_array)
fft_avg=np.mean(abs17060[1:], axis = 0);
logfft17060= 20*np.log10(fft_avg);


inds17060 = np.where(logfft17060 == np.max(logfft17060));
max17060 = logfft17060[inds17060];
print(inds17060, logfft17060[inds17060],'averaged frames for minus 60 dBm @170MHz');
#plt.figure()
plt.plot(fft_freq, logfft17060, label = '-60 dBm @170MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test18060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs18060 = np.abs(fft_array)
fft_avg=np.mean(abs18060[1:], axis = 0);
logfft18060= 20*np.log10(fft_avg);


inds18060 = np.where(logfft18060 == np.max(logfft18060));
max18060 = logfft18060[inds18060];
print(inds18060, logfft18060[inds18060],'averaged frames for minus 60 dBm @180MHz');
#plt.figure()
plt.plot(fft_freq, logfft18060, label = '-60 dBm @180MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');




###################################################################################################################
for i in range(0, frame):
    x = test19060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs19060 = np.abs(fft_array)
fft_avg=np.mean(abs19060[1:], axis = 0);
logfft19060= 20*np.log10(fft_avg);


inds19060 = np.where(logfft19060 == np.max(logfft19060));
max19060 = logfft19060[inds19060];
print(inds19060, logfft19060[inds19060],'averaged frames for minus 60 dBm @190MHz');
#plt.figure()
plt.plot(fft_freq, logfft19060, label = '-60 dBm @190MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');


###################################################################################################################
for i in range(0, frame):
    x = test20060[i]*wind;
    fft_row = 2*(1/NFFT)*np.fft.fft(x, NFFT);
    fft_array[i,:] = fft_row;
    
    
abs20060 = np.abs(fft_array)
fft_avg=np.mean(abs20060[1:], axis = 0);
logfft20060= 20*np.log10(fft_avg);


inds20060 = np.where(logfft20060 == np.max(logfft20060));
max20060 = logfft20060[inds20060];
print(inds20060, logfft20060[inds20060],'averaged frames for minus 60 dBm @200MHz');
#plt.figure()
plt.plot(fft_freq, logfft20060, label = '-60 dBm @200MHz');
plt.legend(loc = 'best');
plt.xlabel('freq in Mhz');
plt.ylabel('log mag');

###################################################################################################################
outminus60_2dbm = [max15060, max16060, max17060, max18060, max19060, max20060];
# Out:
# (array([8075]),) [-46.78110307] averaged frames for minus 60 dBm @150 MHz
# <img src="data:," width="0">
# (array([8079]),) [-45.89515642] averaged frames for minus 60 dBm @160MHz
# (array([8084]),) [-44.7116026] averaged frames for minus 60 dBm @170MHz
# (array([8088]),) [-44.69264755] averaged frames for minus 60 dBm @180MHz
# (array([8093]),) [-44.12151234] averaged frames for minus 60 dBm @190MHz
# (array([8099]),) [-43.52640637] averaged frames for minus 60 dBm @200MHz

# %%
###################################
# %matplotlib notebook
freq = [100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200];

outminus20dbm = outminus20_1dbm + outminus20_2dbm;
outminus30dbm = outminus30_1dbm + outminus30_2dbm;
outminus40dbm = outminus40_1dbm + outminus40_2dbm;
outminus50dbm = outminus50_1dbm + outminus50_2dbm;
outminus60dbm = outminus60_1dbm + outminus60_2dbm;

plt.figure()
plt.plot(freq, outminus20dbm, label = '@-20dBm');
plt.plot(freq, outminus30dbm, label = '@-30dBm');
plt.plot(freq, outminus40dbm, label = '@-40dBm');
plt.plot(freq, outminus50dbm, label = '@-50dBm');
plt.plot(freq, outminus60dbm, label = '@-60dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('mag [dBm]');
plt.show()



#####################################linear plot of magnitude Vs frequency
outminus20dbm = np.array(outminus20dbm);
outminus30dbm = np.array(outminus30dbm);
outminus40dbm = np.array(outminus40dbm);
outminus50dbm = np.array(outminus50dbm);
outminus60dbm = np.array(outminus60dbm);



min20amp = np.power(10, outminus20dbm/20)/np.sqrt(2);
min30amp = np.power(10, outminus30dbm/20)/np.sqrt(2);
min40amp = np.power(10, outminus40dbm/20)/np.sqrt(2);
min50amp = np.power(10, outminus50dbm/20)/np.sqrt(2);
min60amp = np.power(10, outminus60dbm/20)/np.sqrt(2);

#####################################

powmin20dbm = np.power(min20amp, 2)*0.02;
powmin30dbm = np.power(min30amp, 2)*0.02;
powmin40dbm = np.power(min40amp, 2)*0.02;
powmin50dbm = np.power(min50amp, 2)*0.02;
powmin60dbm = np.power(min60amp, 2)*0.02;


plt.figure()
plt.scatter(freq, powmin20dbm, label = '@-20dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('Normalized power [W]');
plt.show()

plt.figure()
plt.scatter(freq, powmin30dbm, label = '@-30dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('Normalized power [W]');
plt.show()

plt.figure()
plt.scatter(freq, powmin40dbm, label = '@-40dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('Normalized power [W]');
plt.show()

plt.figure()
plt.scatter(freq, powmin50dbm, label = '@-50dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('Normalized power [W]');
plt.show()

plt.figure()
plt.scatter(freq, powmin60dbm, label = '@-60dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('Normalized power [W]');
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#####################subtracting the input power from the measured output power
# %matplotlib notebook


resminus20dbm = np.array(powmin20dbm) - 0.100e-4;
resminus30dbm = np.array(powmin30dbm) - 0.100e-5;
resminus40dbm = np.array(powmin40dbm) - 0.100e-6;
resminus50dbm = np.array(powmin50dbm) - 0.100e-7;
resminus60dbm = np.array(powmin60dbm) - 0.100e-8;

plt.figure()
#plt.plot(freq, resminus20dbm, label = 'res@-20dbm');
plt.plot(freq, resminus30dbm, label = 'res@-30dbm');
#plt.plot(freq, resminus40dbm, label = 'res@-40dbm');
#plt.plot(freq, resminus50dbm, label = 'res@-50dbm');
#plt.plot(freq, resminus60dbm, label = 'res@-60dbm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('out - in [watts]');
plt.show()

plt.figure()
plt.plot(freq, resminus40dbm, label = 'res@-40dbm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('out-in[watts]');
plt.show()
# Out:
# <img src="data:," width="0">
# <img src="data:," width="0">

# %%
#######################subtracting @-50dBm residue structure from all other residues
# %matplotlib notebook



res20minus50 = resminus20dbm - resminus50dbm;
res30minus50 = resminus30dbm - resminus50dbm;
res40minus50 = resminus40dbm - resminus50dbm;
res60minus50 = resminus60dbm - resminus50dbm;

plt.figure()
##plt.plot(freq, res20minus50, label = '@-20-50');
plt.plot(freq, res30minus50, label = '@-30-50');
plt.plot(freq, res40minus50, label = '@-40-50');
plt.plot(freq, res60minus50, label = '@-60-50');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('res[dBm]');
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#########################
outminus60dbm = np.array(outminus60dbm) + 20;
outminus50dbm = np.array(outminus50dbm) + 10;
outminus40dbm = outminus40dbm;
outminus30dbm = np.array(outminus30dbm) - 10;
outminus20dbm = np.array(outminus20dbm) - 20;


plt.figure()
plt.plot(freq, outminus20dbm, label = '@-20dBm');
plt.plot(freq, outminus30dbm, label = '@-30dBm');
plt.plot(freq, outminus40dbm, label = '@-40dBm');
plt.plot(freq, outminus50dbm, label = '@-50dBm');
plt.plot(freq, outminus60dbm, label = '@-60dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('mag [dBm]');
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#####################taking into account approximately 10dBm intrinsic gain of the RTL-SDR
##Let's subtract one of the structures..say structure corresponding to minus 60dBm from all the other measurements
# %matplotlib notebook


diff20minus60 = np.array(outminus20dbm) - np.array(outminus60dbm);
diff30minus60 = np.array(outminus30dbm) - np.array(outminus60dbm);
diff40minus60 = np.array(outminus40dbm) - np.array(outminus60dbm);
diff50minus60 = np.array(outminus50dbm) - np.array(outminus60dbm);

###############################################
plt.figure()
plt.plot(freq, diff20minus60, label = '@-20dBm');
plt.plot(freq, diff30minus60, label = '@-30dBm');
plt.plot(freq, diff40minus60, label = '@-40dBm');
plt.plot(freq, diff50minus60, label = '@-50dBm');
##plt.plot(freq, diff60minus60, label = '@-60dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('mag [dBm]');
plt.show()
# Out:
# <img src="data:," width="0">

# %%
ddiff20minus60 = diff20minus60 - 40;
ddiff30minus60 = diff30minus60 - 30;
ddiff40minus60 = diff40minus60 - 20;
ddiff50minus60 = diff50minus60 - 10;

###############################################
# %matplotlib notebook 
plt.figure()
#plt.plot(freq, ddiff20minus60, label = '@-20dBm');
plt.plot(freq, ddiff30minus60, label = '@-30dBm');
plt.plot(freq, ddiff40minus60, label = '@-40dBm');
plt.plot(freq, ddiff50minus60, label = '@-50dBm');
##plt.plot(freq, diff60minus60, label = '@-60dBm');
plt.legend(loc = 'best');
plt.xlabel('freq [MHz]');
plt.ylabel('mag [dBm]');
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##########################Finding out how the real and imaginary parts of the data are related
# %matplotlib notebook


real15030 = test15030.real;
imag15030 = test15030.imag;

###############################finding the frequency response of the real and imaginary parts separately of a frame
##########################say 25th of the test15030
fs = 2.048 ##############sampling frequency in MHz
NFFT = 16384;
#req = np.arange(start = (-NFFT/2)-1, stop = NFFT/2)*fs/NFFT;
fftreal15030 = np.fft.fft(real15030[25], NFFT)*1/NFFT;
fftimag15030 = np.fft.fft(imag15030[25], NFFT)*1/NFFT;
#ftreal15030 = fftreal15030[int(NFFT/2): int(NFFT)];
magreal15030 = 20*np.log10(np.abs(fftreal15030));
magimag15030 = 20*np.log10(np.abs(fftimag15030));
plt.figure()
plt.plot(magreal15030, label = 'real15030');
plt.plot(magimag15030, label = 'imag15030');
plt.xlabel('freq [MHz]');
plt.ylabel('mag [dBm]');
plt.show()
# Out:
# /home/pratush/vishwa/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()
# /home/pratush/vishwa/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log10
# <img src="data:image/png;base64,..." width="572.85">
